# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Define the folders
folders = ['1-No-Xray', '2-2min', '3-1hour']
colors = ['red', 'blue', 'green']  # Colors for each folder

    # Function to filter data
def filter_data(df):
    filtered_df = df
    filtered_df = filtered_df[filtered_df['Cycle Index'] > -1]
    filtered_df.reset_index(drop=True, inplace=True)
    Cycle_index = filtered_df['Cycle Index']
    capacity_data = filtered_df['DChg. Cap.(Ah)']
    return Cycle_index, capacity_data

# Initialize a figure
plt.figure(figsize=(10, 6))

for folder, color in zip(folders, colors):
    # List all Excel files in the folder
    files = [f for f in os.listdir(folder) if f.endswith('.xlsx')]
    files_sort = sorted(files)

    for file in files_sort:
        file_path = os.path.join(folder, file)
        # Read the Excel file
   
# Plot data with different colors
        df = pd.read_excel(file_path, header=0, sheet_name='cycle')
        Cycle_index, capacity_data = filter_data(df)
        plt.scatter(Cycle_index, capacity_data, s=5, color=color, label=f'{folder} - {file}')


plt.ylim(2.6, 3.1)
plt.xlabel('Cycle Index')
plt.ylabel('DChg. Cap.(Ah)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Define the folders
folders = ['1-No-Xray']
colors = ['red']  # Colors for each folder

    # Function to filter data
def filter_data(df):
    filtered_df = df
    filtered_df = filtered_df[filtered_df['Cycle Index'] > -1]
    filtered_df.reset_index(drop=True, inplace=True)
    Cycle_index = filtered_df['Cycle Index']
    capacity_data = filtered_df['DChg. Cap.(Ah)']
    return Cycle_index, capacity_data

# Initialize a figure
plt.figure(figsize=(10, 6))

for folder, color in zip(folders, colors):
    # List all Excel files in the folder
    files = [f for f in os.listdir(folder) if f.endswith('.xlsx')]
    files_sort = sorted(files)

    for file in files_sort:
        file_path = os.path.join(folder, file)
        # Read the Excel file
   
# Plot data with different colors
        df = pd.read_excel(file_path, header=0, sheet_name='cycle')
        Cycle_index, capacity_data = filter_data(df)
        plt.scatter(Cycle_index, capacity_data, s=5, color=color, label=f'{folder} - {file}')


plt.ylim(2.6, 3.1)
plt.xlabel('Cycle Index')
plt.ylabel('DChg. Cap.(Ah)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Define the folders
folders = ['2-2min']
colors = ['blue']  # Colors for each folder

    # Function to filter data
def filter_data(df):
    filtered_df = df
    filtered_df = filtered_df[filtered_df['Cycle Index'] > -1]
    filtered_df.reset_index(drop=True, inplace=True)
    Cycle_index = filtered_df['Cycle Index']
    capacity_data = filtered_df['DChg. Cap.(Ah)']
    return Cycle_index, capacity_data

# Initialize a figure
plt.figure(figsize=(10, 6))

for folder, color in zip(folders, colors):
    # List all Excel files in the folder
    files = [f for f in os.listdir(folder) if f.endswith('.xlsx')]
    files_sort = sorted(files)

    for file in files_sort:
        file_path = os.path.join(folder, file)
        # Read the Excel file
   
# Plot data with different colors
        df = pd.read_excel(file_path, header=0, sheet_name='cycle')
        Cycle_index, capacity_data = filter_data(df)
        plt.scatter(Cycle_index, capacity_data, s=5, color=color, label=f'{folder} - {file}')


plt.ylim(2.6, 3.1)
plt.xlabel('Cycle Index')
plt.ylabel('DChg. Cap.(Ah)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Define the folders
folders = [ '3-1hour']
colors = [ 'green']  # Colors for each folder

    # Function to filter data
def filter_data(df):
    filtered_df = df
    filtered_df = filtered_df[filtered_df['Cycle Index'] > -1]
    filtered_df.reset_index(drop=True, inplace=True)
    Cycle_index = filtered_df['Cycle Index']
    capacity_data = filtered_df['DChg. Cap.(Ah)']
    return Cycle_index, capacity_data

# Initialize a figure
plt.figure(figsize=(10, 6))

for folder, color in zip(folders, colors):
    # List all Excel files in the folder
    files = [f for f in os.listdir(folder) if f.endswith('.xlsx')]
    files_sort = sorted(files)

    for file in files_sort:
        file_path = os.path.join(folder, file)
        # Read the Excel file
   
# Plot data with different colors
        df = pd.read_excel(file_path, header=0, sheet_name='cycle')
        Cycle_index, capacity_data = filter_data(df)
        plt.scatter(Cycle_index, capacity_data, s=5, color=color, label=f'{folder} - {file}')


plt.ylim(2.6, 3.1)
plt.xlabel('Cycle Index')
plt.ylabel('DChg. Cap.(Ah)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Define the folders
folders = ['1-No-Xray', '2-2min', '3-1hour']
colors = ['red', 'blue', 'green']  # Colors for each folder

# Function to filter data
def filter_data(df):
    filtered_df = df[df['Cycle Index'] > -1]
    filtered_df.reset_index(drop=True, inplace=True)
    return filtered_df

# Initialize a figure
plt.figure(figsize=(10, 6))

for folder, color in zip(folders, colors):
    # List all Excel files in the folder
    files = [f for f in os.listdir(folder) if f.endswith('.xlsx')]
    files_sort = sorted(files)
    
    # Initialize a DataFrame to collect all data
    all_data = pd.DataFrame()
    
    for file in files_sort:
        file_path = os.path.join(folder, file)
        # Read the Excel file
        df = pd.read_excel(file_path, header=0, sheet_name='cycle')
        filtered_df = filter_data(df)
        
        all_data = pd.concat([all_data, filtered_df], ignore_index=True)
    
    # Calculate the mean DChg. Cap.(Ah) for each Cycle Index
    mean_data = all_data.groupby('Cycle Index')['DChg. Cap.(Ah)'].mean().reset_index()
    
    # Plot the mean data
    plt.plot(mean_data['Cycle Index'], mean_data['DChg. Cap.(Ah)'], color=color, label=folder)

# Adjust plot settings
plt.ylim(2.5, 3.1)
plt.xlabel('Cycle Index')
plt.ylabel('Average DChg. Cap.(Ah)')
plt.title('Average DChg. Cap.(Ah) vs Cycle Index per Folder')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Define the folders
folders = ['1-No-Xray', '2-2min', '3-1hour']
colors = ['red', 'blue', 'green']  # Colors for each folder

# Function to filter data
def filter_data(df):
    filtered_df = df[df['Cycle Index'] > -1]
    filtered_df.reset_index(drop=True, inplace=True)
    return filtered_df

# Initialize a figure
plt.figure(figsize=(10, 6))

for folder, color in zip(folders, colors):
    # List all Excel files in the folder
    files = [f for f in os.listdir(folder) if f.endswith('.xlsx')]
    files_sort = sorted(files)
    
    # Initialize a DataFrame to collect all data
    all_data = pd.DataFrame()
    
    for file in files_sort:
        file_path = os.path.join(folder, file)
        # Read the Excel file
        df = pd.read_excel(file_path, header=0, sheet_name='cycle')
        filtered_df = filter_data(df)
        
        all_data = pd.concat([all_data, filtered_df], ignore_index=True)
    
    # Calculate the mean DChg. Cap.(Ah) for each Cycle Index
    mean_data = all_data.groupby('Cycle Index')['T1 Maximum temperature of discharging(℃)'].mean().reset_index()
    
    # Plot the mean data
    plt.plot(mean_data['Cycle Index'], mean_data['T1 Maximum temperature of discharging(℃)'], color=color, label=folder)

# Adjust plot settings
plt.ylim(45, 55)
plt.xlabel('Cycle Index')
plt.ylabel('Average Maximum DChg temp')
plt.title('Average Maximum DChg temp vs Cycle Index per Folder')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/jinhong/.pyenv/versions/glimpse_env3/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
# ...
